# %%
import pandas as pd

# %%
df = pd.read_csv('deep_essays_dataset.csv')
df.head()
# Out:
#    Unnamed: 0      title                                        description  \
# 0           0  Addiction  Passion stabs, unrequited love hurts and taboo...
# 1           1  Addiction  The fear of missing out haunts our social netw...
# 2           2  Addiction  The neuroscientific picture of addiction overl...
# 3           3  Addiction  The new science of addiction makes 12-step pro...
# 4           4  Addiction  Cutting brings relief because emotion and pain...
#
#                                                essay        authors  \
# 0  Omer Bonne means well; that much is certain. A...    Angela Chen
# 1  Here’s a test you might enjoy: rate these scen...    Jacob Burak
# 2  Human beings crave all sorts of things: coffee...  Zoey Lavallee
# 3  I hear a single voice as I walk up the steps t...   Rebecca Ruiz
# 4  Here’s what I remember about the first time I ...  Carrie Arnold
#
#                                           source_url  \
# ...

# %%
for i in df['title'].unique():
    print(i)
# Out:
# Addiction
# Ageing and death
# Animals and humans
# Anthropology
# Archaeology
# Architecture
# Art
# Astronomy
# Automation and robotics
# Beauty and aesthetics
# Bioethics
# Biography and memoir
# Biology
# Biotechnology
# Chemistry
# Childhood and adolescence
# Cities
# Cognition and intelligence
# Comparative philosophy
# Complexity
# Computing and artificial intelligence
# Consciousness and altered states
# Cosmology
# Cosmopolitanism
# Dance and theatre
# Death
# Deep time
# Demography and migration
# Design and fashion
# Earth science and climate
# Ecology and environmental sciences
# Economic history
# Economics
# Education
# Engineering
# Environmental history
# Ethics
# Evolution
# Fairness and equality
# Family life
# Film and visual culture
# Food and drink
# Future of technology
# Gender
# Gender and identity
# Genetics
# Global history
# History
# History of ideas
# History of science
# History of technology
# Home
# Human evolution
# Human reproduction
# ...

# %%
df['id'] = str(abs(df.description.map(hash)))
df
# Out:
#           title                                        description  \
# 0     Addiction  Passion stabs, unrequited love hurts and taboo...
# 1     Addiction  The fear of missing out haunts our social netw...
# 2     Addiction  The neuroscientific picture of addiction overl...
# 3     Addiction  The new science of addiction makes 12-step pro...
# 4     Addiction  Cutting brings relief because emotion and pain...
# ...         ...                                                ...
# 2230       Work  It takes diplomacy, anthropology and psycholog...
# 2231       Work  Jobs have become, for so many, a relentless, u...
# 2232       Work  Economists believe in full employment. America...
# 2233       Work  There is always a demand for more jobs. But wh...
# 2234       Work  Men from the Shetland Islands worked the whali...
#
#                                                   essay            authors  \
# 0     Omer Bonne means well; that much is certain. A...        Angela Chen
# ...

# %%
df.to_csv('deep_essays_dataset.csv')
df
# Out:
#           title                                        description  \
# 0     Addiction  Passion stabs, unrequited love hurts and taboo...
# 1     Addiction  The fear of missing out haunts our social netw...
# 2     Addiction  The neuroscientific picture of addiction overl...
# 3     Addiction  The new science of addiction makes 12-step pro...
# 4     Addiction  Cutting brings relief because emotion and pain...
# ...         ...                                                ...
# 2230       Work  It takes diplomacy, anthropology and psycholog...
# 2231       Work  Jobs have become, for so many, a relentless, u...
# 2232       Work  Economists believe in full employment. America...
# 2233       Work  There is always a demand for more jobs. But wh...
# 2234       Work  Men from the Shetland Islands worked the whali...
#
#                                                   essay            authors  \
# 0     Omer Bonne means well; that much is certain. A...        Angela Chen
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df[df['id'] == 4019930830873790000]
# Out:
# Empty DataFrame
# Columns: [title, description, essay, authors, source_url, thumbnail_url, id]
# Index: []

# %%
df
# Out:
#           title                                        description  \
# 0     Addiction  Passion stabs, unrequited love hurts and taboo...
# 1     Addiction  The fear of missing out haunts our social netw...
# 2     Addiction  The neuroscientific picture of addiction overl...
# 3     Addiction  The new science of addiction makes 12-step pro...
# 4     Addiction  Cutting brings relief because emotion and pain...
# ...         ...                                                ...
# 2230       Work  It takes diplomacy, anthropology and psycholog...
# 2231       Work  Jobs have become, for so many, a relentless, u...
# 2232       Work  Economists believe in full employment. America...
# 2233       Work  There is always a demand for more jobs. But wh...
# 2234       Work  Men from the Shetland Islands worked the whali...
#
#                                                   essay            authors  \
# 0     Omer Bonne means well; that much is certain. A...        Angela Chen
# ...
